# %%
# Plot training info
# Hella Importnt
import numpy as np
import scipy as sp
import csv
import matplotlib.pyplot as plt
import sys
import google
from IPython.display import display, Image 
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# Generate loss plots
# --------------- Latex Plot Beautification --------------------------
fig_width_pt = 246.0  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inch
golden_mean = (np.sqrt(5)-1.0)/2.0         # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_width*golden_mean      # height in inches
fig_size =  [fig_width+1,fig_height+1]
params = {'backend': 'ps',
          'axes.labelsize': 14,
          'text.fontsize': 14,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'text.usetex': False,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
# --------------- Latex Plot Beautification --------------------------
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Before using:
# -bash $CAFFE_HOME/tools/extra/parse_log.sh /tmp/caffe.INFO
# (creates two tables, caffe.INFO.test, caffe.INFO.train)

train = {}
tmp = np.loadtxt('caffe.INFO.softmax_centerdepth.train')
train['iters'], train['seconds'], train['loss'], train['learn_rate'] = tmp[:,0], tmp[:,1], tmp[:,2], tmp[:,3]
# Iters Seconds TrainingLoss LearningRate

plt.subplot(211)
plt.semilogy(train['iters'],train['loss'],'b',lw=2)
plt.ylabel('loss')
plt.title('Train Set')
#plt.ylim(0,30)
#plt.xlim(0,2000)

# plt.subplot(212)
# plt.plot(train['iters'],train['learn_rate'],'b')
# plt.xlabel('iters')
# plt.ylabel('learn rate')
# plt.show()

test = {}
tmp = np.loadtxt('caffe.INFO.softmax_centerdepth.test')
test['iters'], test['seconds'], test['accuracy'], test['loss'] = tmp[:,0], tmp[:,1], tmp[:,2], tmp[:,3]
# Iters Seconds TrainingLoss LearningRate
plt.subplot(212)
plt.plot(test['iters'],100*test['accuracy'],'bo-', lw=2)
#plt.title('Validation Accuracy')
plt.xlabel('iterations')
plt.ylabel('Val. Accuracy')
#plt.show()
plt.savefig('Softmax_train.pdf')

# %%
# Plot histograms of depths in a dataset:

in_file = 'train/NYUv2/train_full_167_v2/index_16_norm.txt'


import csv

f = open(in_file,'r')
depths = []
csvf = csv.reader(f)

for row in csvf:
    tmp = row[0].split(' ',1)
    depths.append(tmp[1])
print np.unique(depths)
plt.plot(np.bincount(depths)/(0.01*len(depths)))
plt.ylabel('Occurance Percent')
plt.xlabel('Bin Number')
plt.xlim([1,len(np.unique(depths))])
# Out:
# ['1' '10' '11' '12' '13' '14' '15' '16' '2' '3' '4' '5' '6' '7' '8' '9']
# (1, 16)

# %%
# Generate loss plots
# --------------- Latex Plot Beautification --------------------------
fig_width_pt = 246.0  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inch
golden_mean = (sqrt(5)-1.0)/2.0         # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_width*golden_mean      # height in inches
fig_size =  [fig_width+1,fig_height+1]
params = {'backend': 'ps',
          'axes.labelsize': 10,
          'text.fontsize': 10,
          'legend.fontsize': 10,
          'xtick.labelsize': 8,
          'ytick.labelsize': 8,
          'text.usetex': False,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
# --------------- Latex Plot Beautification --------------------------



train = {}
tmp = np.loadtxt('caffe.INFO.euclidean_v3_16_norm_realmean_20k_assem.train')
train['iters'], train['seconds'], train['loss'], train['learn_rate'] = tmp[:,0], tmp[:,1], tmp[:,2], tmp[:,3]
# Iters Seconds TrainingLoss LearningRate

train2 = {}
tmp = np.loadtxt('caffe.INFO.euclidean_v3_16_norm_superpixel_avg_20k.train')
train2['iters'], train2['seconds'], train2['loss'], train2['learn_rate'] = tmp[:,0], tmp[:,1], tmp[:,2], tmp[:,3]


#plt.subplot(211)
plt.semilogy(train['iters'],train['loss'],'b',label='Center Depth')
plt.semilogy(train2['iters'],train2['loss'],'r',label='Superpixel Avg')

plt.ylabel('loss')
plt.xlabel('Iters')

plt.title('Train Set')
plt.xlim(0,20000)
plt.ylim(0,14)
plt.legend()

plt.savefig('training_loss.eps')

# %%
   import pylab
   from pylab import arange,pi,sin,cos,sqrt
   fig_width_pt = 246.0  # Get this from LaTeX using \showthe\columnwidth
   inches_per_pt = 1.0/72.27               # Convert pt to inch
   golden_mean = (sqrt(5)-1.0)/2.0         # Aesthetic ratio
   fig_width = fig_width_pt*inches_per_pt  # width in inches
   fig_height = fig_width*golden_mean      # height in inches
   fig_size =  [fig_width,fig_height]
   params = {'backend': 'ps',
             'axes.labelsize': 10,
             'text.fontsize': 10,
             'legend.fontsize': 10,
             'xtick.labelsize': 8,
             'ytick.labelsize': 8,
             'text.usetex': False,
             'figure.figsize': fig_size}
   pylab.rcParams.update(params)
   # Generate data
   x = pylab.arange(-2*pi,2*pi,0.01)
   y1 = sin(x)
   y2 = cos(x)
   # Plot data
   # Plot data
   pylab.figure(1)
   pylab.clf()
   pylab.axes([0.125,0.2,0.95-0.125,0.95-0.2])
   pylab.plot(x,y1,'g:',label='sin(x)')
   pylab.plot(x,y2,'-b',label='cos(x)')
   pylab.xlabel('x (radians)')
   pylab.ylabel('y')
   pylab.legend()
   pylab.savefig('fig2.eps')
