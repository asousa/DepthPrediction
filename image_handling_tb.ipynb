# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from image_handling import load_dataset
from image_handling import segment_image

# %%
[images, depths] = load_dataset('nyu_depth_v2_labeled.mat')

# %%
n = 1030
test_image = np.array(images[n, ...])
test_image
mask = segment_image(test_image, no_segments=300)
from skimage.segmentation import mark_boundaries
fig1 = plt.figure()
axes1 = fig1.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.imshow(np.transpose(mark_boundaries(np.transpose(test_image, (1,2,0)) , mask), (1, 0, 2)))

# %%
from image_handling import calculate_sp_centroids

centroids = calculate_sp_centroids(mask)

print centroids.shape
center_pixels = np.array(centroids, dtype=int)

fig2 = plt.figure()
axes2 = fig2.add_axes([0.1, 0.1, 0.8, 0.8])
axes2.plot(centroids[0,:], centroids[1, :], '.')
# Out:
# (2, 300)

# %%
from image_handling import gather_regions

sections = gather_regions(test_image, centroids, x_window_size=40, y_window_size=40)

fig3 = plt.figure()
axes3 = fig3.add_axes([0.1, 0.1, 0.8, 0.8])
axes3.imshow(sections[299, ...].transpose())

# %%
from image_handling import load_dataset_segments

[image_segs, depth_segs] = load_dataset_segments('nyu_depth_v2_labeled.mat',
                                                 images=(1020,),
                                                 no_superpixels=493,
                                                 x_window_size=40,
                                                 y_window_size=40)

print image_segs.shape

fig4 = plt.figure()
axes4 = fig4.add_axes([0.1, 0.1, 0.8, 0.8])
axes4.imshow(image_segs[200, ...].transpose())
# Out:
# (494, 3, 81, 81)

# %%
from image_handling import create_segments_dataset
data_file = create_segments_dataset('nyu_depth_v2_labeled.mat', 'extracted_segments.mat',
                no_superpixels=700, x_window_size=227, y_window_size=227, images=(1020,))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-9f50d281099c> in <module>()
#       1 from image_handling import create_segments_dataset
#       2 data_file = create_segments_dataset('nyu_depth_v2_labeled.mat', 'extracted_segments.mat',
# ----> 3                 no_superpixels=700, x_window_size=227, y_window_size=227, images=(1020,))
#
# /home/vlf/dfreese/DepthPrediction/image_handling.pyc in create_segments_dataset(input_filename, output_filename, no_superpixels, x_window_size, y_window_size, images)
#     149         no_segments = no_superpixels * len(images)
#     150
# --> 151         output_file = h5py.File(output_filename, 'w')
#     152 	image_segments = output_file.create_dataset("data",
#     153                 (no_segments, image_set.shape[1], 2 * x_window_size + 1, 2 * y_window_size + 1),
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, **kwds)
#     229
#     230                 fapl = make_fapl(driver, libver, **kwds)
# --> 231                 fid = make_fid(name, mode, userblock_size, fapl)
#     232
#     233             Group.__init__(self, fid)
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl)
#      82         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#      83     elif mode == 'w':
# ---> 84         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#      85     elif mode == 'a':
#      86         # Open in append mode (read/write).
#
# /usr/local/lib/python2.7/dist-packages/h5py/_objects.so in h5py._objects.with_phil.wrapper (/tmp/pip_build_root/h5py/h5py/_objects.c:2453)()
#
# /usr/local/lib/python2.7/dist-packages/h5py/_objects.so in h5py._objects.with_phil.wrapper (/tmp/pip_build_root/h5py/h5py/_objects.c:2410)()
#
# /usr/local/lib/python2.7/dist-packages/h5py/h5f.so in h5py.h5f.create (/tmp/pip_build_root/h5py/h5py/h5f.c:1960)()
#
# IOError: Unable to create file (Unable to truncate a file which is already open)

# %%
depths_min = np.min(depths)
depths_max = np.max(depths)

# %%
print depths_min, depths_max
depth_cuts = np.logspace(np.log(depths_min), np.log(depths_max), num=20, base=np.e)
# Out:
# 0.7133 9.99547

# %%
def log_pixelate_values(array, min_val, max_val, pixels):
    cuts = np.logspace(np.log(min_val), np.log(max_val), num=pixels, base=np.e)
    array_vals = np.array(array[:])
    val = np.reshape(np.digitize(array_vals.flatten(), cuts), array.shape)
    return val

# %%
n = 1304
log_pixelated_image = log_pixelate_values(depths[n,...], depths_min, depths_max, 1024)

fig5 = plt.figure()
axes5 = fig5.add_axes([0.1, 0.1, 0.8, 0.8])
axes6 = fig5.add_axes([1, 0.1, 0.8, 0.8])
axes5.imshow(depths[n,...].transpose())
axes6.imshow(log_pixelated_image.transpose())

# %%
log_pixelated_image = log_pixelate_values(depths, depths_min, depths_max, 512)

n = 1304
fig5 = plt.figure()
axes5 = fig5.add_axes([0.1, 0.1, 0.8, 0.8])
axes6 = fig5.add_axes([1, 0.1, 0.8, 0.8])
axes5.imshow(depths[n,...].transpose())
axes6.imshow(log_pixelated_image[n,...].transpose())
